# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa import stattools
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 6)
import numpy
from math import sqrt

# %%
from statsmodels.tsa.arima_model import ARIMAResults

# %%
loaded = ARIMAResults.load('model1.pkl')

# %%
loaded.plot_diagnostics()
plt.plot()
# Out:
# []

# %%
loaded.forecast(steps=24)
# Out:
# 2018-08-22 00:00:00   -5.093458
# 2018-08-22 01:00:00   -4.723217
# 2018-08-22 02:00:00   -4.444773
# 2018-08-22 03:00:00   -4.204242
# 2018-08-22 04:00:00   -4.019858
# 2018-08-22 05:00:00   -3.866226
# 2018-08-22 06:00:00   -3.791880
# 2018-08-22 07:00:00   -3.789629
# 2018-08-22 08:00:00   -3.852476
# 2018-08-22 09:00:00   -4.030450
# 2018-08-22 10:00:00   -4.592040
# 2018-08-22 11:00:00   -4.788808
# 2018-08-22 12:00:00   -4.929494
# 2018-08-22 13:00:00   -4.890380
# 2018-08-22 14:00:00   -5.086138
# 2018-08-22 15:00:00   -5.423005
# 2018-08-22 16:00:00   -5.361032
# 2018-08-22 17:00:00   -5.172026
# 2018-08-22 18:00:00   -4.851958
# 2018-08-22 19:00:00   -4.724009
# 2018-08-22 20:00:00   -4.941124
# 2018-08-22 21:00:00   -4.924102
# 2018-08-22 22:00:00   -5.284825
# 2018-08-22 23:00:00   -5.492198
# Freq: H, dtype: float64
