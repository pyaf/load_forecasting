# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa import stattools
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 6)
import numpy
from math import sqrt

# %%
from statsmodels.tsa.arima_model import ARIMAResults

# %%
loaded = ARIMAResults.load('model1.pkl')

# %%
loaded.plot_diagnostics()
plt.plot()
# Out:
# []

# %%
loaded.forecast(steps=24)
# Out:
# 2018-08-22 00:00:00   -5.707225
# 2018-08-22 01:00:00   -5.292378
# 2018-08-22 02:00:00   -4.980386
# 2018-08-22 03:00:00   -4.710875
# 2018-08-22 04:00:00   -4.504272
# 2018-08-22 05:00:00   -4.332130
# 2018-08-22 06:00:00   -4.248831
# 2018-08-22 07:00:00   -4.246307
# 2018-08-22 08:00:00   -4.316730
# 2018-08-22 09:00:00   -4.516152
# 2018-08-22 10:00:00   -5.145418
# 2018-08-22 11:00:00   -5.365896
# 2018-08-22 12:00:00   -5.523534
# 2018-08-22 13:00:00   -5.479707
# 2018-08-22 14:00:00   -5.699052
# 2018-08-22 15:00:00   -6.076512
# 2018-08-22 16:00:00   -6.007066
# 2018-08-22 17:00:00   -5.795279
# 2018-08-22 18:00:00   -5.436653
# 2018-08-22 19:00:00   -5.293287
# 2018-08-22 20:00:00   -5.536543
# 2018-08-22 21:00:00   -5.517481
# 2018-08-22 22:00:00   -5.921668
# 2018-08-22 23:00:00   -6.154024
# Freq: H, dtype: float64
